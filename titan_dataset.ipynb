# %% [markdown]
# <a href="https://colab.research.google.com/github/bhavanitha-jpg/Internquest/blob/main/titan_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedGroupKFold, cross_val_score

# %%
df=pd.read_csv("/content/titanic_dataset.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.dropna(axis=0, subset=["Age","Cabin","Embarked"], inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
X=df.drop(["Survived"], axis=1)
Y= df["Survived"]
df
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
X
# Out:
#      PassengerId  Pclass                                               Name  \
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 6              7       1                            McCarthy, Mr. Timothy J
# 10            11       3                    Sandstrom, Miss. Marguerite Rut
# 11            12       1                           Bonnell, Miss. Elizabeth
# ..           ...     ...                                                ...
# 871          872       1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 872          873       1                           Carlsson, Mr. Frans Olof
# 879          880       1      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 887          888       1                       Graham, Miss. Margaret Edith
# 889          890       1                              Behr, Mr. Karl Howell
#
# ...

# %%
Y
# Out:
# 1      1
# 3      1
# 6      0
# 10     1
# 11     1
#       ..
# 871    1
# 872    0
# 879    1
# 887    1
# 889    1
# Name: Survived, Length: 183, dtype: int64

# %%
num_col= [cname for cname in df.columns if df[cname].dtype in ['int64','float64']]
X=df

# %%
KF = KFold(n_splits=5)
print("Data Splitting into following number of Folds")
KF.get_n_splits(X,Y)
# Out:
# Data Splitting into following number of Folds
# 5

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.20)

# %%
import pandas as pd
import numpy as np
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
from sklearn.metrics import accuracy_score


numerical_features = df.select_dtypes(include=['number']).columns
X = df[numerical_features]

if 'Survived' in X.columns:
    X = X.drop('Survived', axis=1)
Y = df["Survived"]

clf = DecisionTreeClassifier()
KF = KFold(n_splits=5)
for train_index, test_index in KF.split(X, Y):
    clf.fit(X.iloc[train_index, :], Y.iloc[train_index])
    pred = clf.predict(X.iloc[test_index, :])
    print(round(accuracy_score(Y.iloc[test_index], pred), 5))
# Out:
# 0.54054
# 0.64865
# 0.64865
# 0.72222
# 0.72222

# %%
cv= cross_val_score(DecisionTreeClassifier(), X,Y, cv=5, scoring="accuracy")
cv
# Out:
# array([0.35135135, 0.48648649, 0.40540541, 0.63888889, 0.69444444])
